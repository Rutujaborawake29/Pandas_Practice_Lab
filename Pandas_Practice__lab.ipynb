# %% [markdown]
# <a href="https://colab.research.google.com/github/Rutujaborawake29/Pandas_Practice_Lab/blob/main/Pandas_Practice__lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Pandas Practice lab**

# %%
import pandas as pd

# %%
dict1 ={'Name':['Priyang','Aadhya','Krisha','Vedant','Parshv',
                'Mittal','Archana'],
                'Marks':[98,89,99,87,90,83,99],
                'Gender':['Male','Female','Female','Male','Male',
                         'Female','Female']
               }
df=pd.DataFrame(dict1)
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.head(3)
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female

# %%
df.tail(3)
# Out:
#       Name  Marks  Gender
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.shape
# Out:
# (7, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   7 non-null      int64
#  2   Gender  7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 296.0+ bytes

# %%
df.describe()
# Out:
#            Marks
# count   7.000000
# mean   92.142857
# std     6.491753
# min    83.000000
# 25%    88.000000
# 50%    90.000000
# 75%    98.500000
# max    99.000000

# %%
df.ndim
# Out:
# 2

# %%
df.isnull()
# Out:
#     Name  Marks  Gender
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    4
# Male      3
# Name: count, dtype: int64

# %%
df['Marks']
# Out:
# 0    98
# 1    89
# 2    99
# 3    87
# 4    90
# 5    83
# 6    99
# Name: Marks, dtype: int64

# %%
df['Marks']>=90
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
(df['Marks']>=90) &  (df['Marks']<=100)
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# Name: Marks, dtype: bool

# %%
len(df[(df['Marks']>=90) &  (df['Marks']<=100)])
# Out:
# 4

# %%
df['Marks'].between(90,100).sum()
# Out:
# 4

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df['Marks'].mean()
# Out:
# 92.14285714285714

# %%
df['Marks'].median()
# Out:
# 90.0

# %%
df['Marks'].sum()
# Out:
# 645

# %%
df['Marks'].min()
# Out:
# 83

# %%
df['Marks'].max()
# Out:
# 99

# %%
def marks(x):
  return x//2

# %%
df['Marks'].apply(marks)
# Out:
# 0    49
# 1    44
# 2    49
# 3    43
# 4    45
# 5    41
# 6    49
# Name: Marks, dtype: int64

# %%
df['half_marks']=df['Marks'].apply(marks)

# %%
df
# Out:
#       Name  Marks  Gender  half_marks
# 0  Priyang     98    Male          49
# 1   Aadhya     89  Female          44
# 2   Krisha     99  Female          49
# 3   Vedant     87    Male          43
# 4   Parshv     90    Male          45
# 5   Mittal     83  Female          41
# 6  Archana     99  Female          49

# %%
df['Marks'].apply(lambda x:x/2)
# Out:
# 0    49.0
# 1    44.5
# 2    49.5
# 3    43.5
# 4    45.0
# 5    41.5
# 6    49.5
# Name: Marks, dtype: float64

# %%
df['Gender'].map({'Male':1,'Female':0})
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# Name: Gender, dtype: int64

# %%
df['Male_Female']=df['Gender'].map({'Male':1,'Female':0})

# %%
df
# Out:
#       Name  Marks  Gender  half_marks  Male_Female
# 0  Priyang     98    Male          49            1
# 1   Aadhya     89  Female          44            0
# 2   Krisha     99  Female          49            0
# 3   Vedant     87    Male          43            1
# 4   Parshv     90    Male          45            1
# 5   Mittal     83  Female          41            0
# 6  Archana     99  Female          49            0

# %%
df['Male_Female'].sum()
# Out:
# 3

# %%
df.drop(['Male_Female','half_marks'],axis=1,inplace=True) #inplace=true makes permanet

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.columns #attribute
# Out:
# Index(['Name', 'Marks', 'Gender'], dtype='object')

# %%
df.index #attribute
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df.sort_values(by='Marks') #ascending
# Out:
#       Name  Marks  Gender
# 5   Mittal     83  Female
# 3   Vedant     87    Male
# 1   Aadhya     89  Female
# 4   Parshv     90    Male
# 0  Priyang     98    Male
# 2   Krisha     99  Female
# 6  Archana     99  Female

# %%
df.sort_values(by='Marks',ascending=False) #descending
# Out:
#       Name  Marks  Gender
# 2   Krisha     99  Female
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4   Parshv     90    Male
# 1   Aadhya     89  Female
# 3   Vedant     87    Male
# 5   Mittal     83  Female

# %%
df.sort_values(by=['Marks','Gender'],ascending=False)
# Out:
#       Name  Marks  Gender
# 2   Krisha     99  Female
# 6  Archana     99  Female
# 0  Priyang     98    Male
# 4   Parshv     90    Male
# 1   Aadhya     89  Female
# 3   Vedant     87    Male
# 5   Mittal     83  Female

# %%
df
# Out:
#       Name  Marks  Gender
# 0  Priyang     98    Male
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 3   Vedant     87    Male
# 4   Parshv     90    Male
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df[df['Gender']=='Female']
# Out:
#       Name  Marks  Gender
# 1   Aadhya     89  Female
# 2   Krisha     99  Female
# 5   Mittal     83  Female
# 6  Archana     99  Female

# %%
df[df['Gender']=='Female'][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99

# %%
df[df['Gender'].isin(['Female'])][['Name','Marks']]
# Out:
#       Name  Marks
# 1   Aadhya     89
# 2   Krisha     99
# 5   Mittal     83
# 6  Archana     99
